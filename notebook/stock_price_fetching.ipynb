# %%
import pandas as pd
import yfinance as yf

# %%
# Load data from CSV into DataFrame
stock_data = pd.read_csv("../data/raw_analyst_ratings.csv", na_values=["NA", "N/A"])

# %%
stock_data.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# ...

# %%
# Determine date ranges for each stock
date_ranges = stock_data.groupby("publisher")["date"].agg(["min", "max"])
print(date_ranges)
# Out:
#                                             min                        max
# publisher
# 47ertrends                  2012-02-11 00:00:00        2012-02-18 00:00:00
# AARP                        2020-05-19 00:00:00  2020-05-21 11:54:21-04:00
# ABNNewswire                 2011-03-13 00:00:00        2011-03-23 00:00:00
# Aakin                       2010-01-05 00:00:00        2010-01-07 00:00:00
# Aaron Jackson.Ed            2015-12-29 00:00:00        2016-02-19 00:00:00
# ...                                         ...                        ...
# vic@forextraininggroup.com  2018-09-06 00:00:00        2018-09-06 00:00:00
# vishwanath@benzinga.com     2020-04-07 00:00:00  2020-06-01 05:11:01-04:00
# vivek.proactive@gmail.com   2017-11-13 00:00:00        2017-11-17 00:00:00
# wallstreet1928              2009-09-14 00:00:00        2009-11-06 00:00:00
# webmaster                   2009-08-16 00:00:00        2015-10-29 00:00:00
#
# [1034 rows x 2 columns]

# %%
# Define date_ranges DataFrame
date_ranges = stock_data.groupby("publisher")["date"].agg(["min", "max"])

# Loop through each stock symbol
for publisher, date_range in date_ranges.iterrows():
    start_date = date_range["min"]
    end_date = date_range["max"]

    # Fetch stock data for the current publisher based on the date range
    # You can use this information to fetch stock data using yfinance or any other method
    print(f"Publisher: {publisher}, Start Date: {start_date}, End Date: {end_date}")
# Out:
# Publisher: 47ertrends, Start Date: 2012-02-11 00:00:00, End Date: 2012-02-18 00:00:00
# Publisher: AARP, Start Date: 2020-05-19 00:00:00, End Date: 2020-05-21 11:54:21-04:00
# Publisher: ABNNewswire, Start Date: 2011-03-13 00:00:00, End Date: 2011-03-23 00:00:00
# Publisher: Aakin, Start Date: 2010-01-05 00:00:00, End Date: 2010-01-07 00:00:00
# Publisher: Aaron Jackson.Ed, Start Date: 2015-12-29 00:00:00, End Date: 2016-02-19 00:00:00
# Publisher: Aaron Levitt, Start Date: 2010-04-27 00:00:00, End Date: 2011-07-21 00:00:00
# Publisher: Abe Raymond, Start Date: 2011-08-08 00:00:00, End Date: 2012-01-27 00:00:00
# Publisher: Abhi Rao, Start Date: 2011-12-13 00:00:00, End Date: 2012-01-25 00:00:00
# Publisher: Abigail Field, Start Date: 2014-04-03 00:00:00, End Date: 2014-06-12 00:00:00
# Publisher: Above Average Odds, Start Date: 2010-01-10 00:00:00, End Date: 2011-08-09 00:00:00
# Publisher: Accointing, Start Date: 2019-12-02 00:00:00, End Date: 2019-12-02 00:00:00
# ...
